# %%
import pandas as pd

# %%
df=pd.read_csv('/50_Startups (1).csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    object
#  4   Profit           108 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
le=LabelEncoder()
df['State']=le.fit_transform(df['State'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    int64
#  4   Profit           108 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 4.3 KB

# %%
x=df.drop('Profit',axis=1)
y=df['Profit']

# %%
x
# Out:
#      R&D Spend  Administration  Marketing Spend  State
# 0    165349.20       136897.80        471784.10      2
# 1    162597.70       151377.59        443898.53      0
# 2    153441.51       101145.55        407934.54      1
# 3    144372.41       118671.85        383199.62      2
# 4    142107.34        91391.77        366168.42      1
# ..         ...             ...              ...    ...
# 103  119943.24       156547.42        256512.92      1
# 104  114523.61       122616.84        261776.23      2
# 105   78013.11       121597.55        264346.06      0
# 106   94657.16       145077.58        282574.31      2
# 107   91749.16       114175.79        294919.57      1
#
# [108 rows x 4 columns]

# %%
y
# Out:
# 0      192261.83
# 1      191792.06
# 2      191050.39
# 3      182901.99
# 4      166187.94
#          ...
# 103    132602.65
# 104    129917.04
# 105    126992.93
# 106    125370.37
# 107    124266.90
# Name: Profit, Length: 108, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2, random_state=12)

# %%
xtrain
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 12   93863.75       127320.38        249839.44      1
# 68   65605.48       153032.06        107138.38      2
# 1   162597.70       151377.59        443898.53      0
# 15  114523.61       122616.84        261776.23      2
# 38   20229.59        65947.93        185265.10      2
# ..        ...             ...              ...    ...
# 3   144372.41       118671.85        383199.62      2
# 2   153441.51       101145.55        407934.54      1
# 6   134615.46       147198.87        127716.82      0
# 27   72107.60       127864.55        353183.81      2
# 75   28663.76       127056.21        201126.82      1
#
# [86 rows x 4 columns]

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (86, 4) (22, 4) (86,) (22,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
lr=LinearRegression()
rr=RandomForestRegressor()

# %%
lr.fit(xtrain,ytrain)
rr.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
ypred=lr.predict(xtest)
yrrpred=rr.predict(xtest)

# %%
ypred
# Out:
# array([ 79056.44748665, 120512.25397097, 111565.13999838, 153756.87546174,
#         85044.50038713, 148846.88260974, 128082.267186  , 120512.25397097,
#        110006.23757341,  72719.90047486, 159813.92391625,  77670.00480991,
#         97352.6249148 , 131633.88230628, 152093.64144472, 152093.64144472,
#         63728.21792571, 173206.13483155,  63728.21792571, 153756.87546174,
#        129394.76526943, 111565.13999838])

# %%
yrrpred
# Out:
# array([ 90099.3412, 124744.0509, 138652.1889, 131682.3713,  81738.9634,
#        133491.8483, 134815.0539, 124744.0509, 108154.1871,  76446.9839,
#        154248.4808,  81549.5521,  99575.0722, 126115.9877, 128175.3899,
#        128175.3899,  81783.8108, 178586.3358,  81783.8108, 131682.3713,
#        140788.3672, 138652.1889])

# %%
from sklearn.metrics import confusion_matrix,r2_score
r2_score(ytest,ypred)
# Out:
# 0.9395875376012648

# %%
r2_score(ytest,yrrpred)
# Out:
# 0.8211417297271052
